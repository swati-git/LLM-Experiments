# %% [markdown]
# <a href="https://colab.research.google.com/github/swati-git/LLM-Experiments/blob/main/AnalyzingADocument_No_PromptTemplate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Read the document

# %%
import os
current_directory = os.getcwd()
#print(os.getcwd())

import pkgutil
for _, name, _ in pkgutil.iter_modules([current_directory]):
    print(name)


os.environ["OPENAI_API_KEY"] = "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"

# %%
state_of_the_union = ""

# %%
import sys

print(sys.path)
#['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython']
#['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython']

# %%
# !pip list

# %%
# !pip install langchain

# %%
# !pip install OpenAI

#Successfully installed OpenAI-1.3.5 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2

# %%
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# %%
from langchain.chains import AnalyzeDocumentChain
#Reference to AnalyzeDocumentChain https://github.com/langchain-ai/langchain/blob/391f200eaab9af587eea902b264f2d3af929b268/libs/langchain/langchain/chains/combine_documents/base.py#L159
