# %% [markdown]
# <a href="https://colab.research.google.com/github/swati-git/LLM-Experiments/blob/main/Cookbook_References.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/langchain-ai/langchain/blob/master/cookbook/analyze_document.ipynb
